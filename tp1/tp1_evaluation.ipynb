# %% [markdown]
# ### <center> compte rendu TP1: évaluation des performances </center>

# %% [markdown]
# ![WhatsApp%20Image%202020-10-30%20at%2018.45.53%20%281%29.jpeg](attachment:WhatsApp%20Image%202020-10-30%20at%2018.45.53%20%281%29.jpeg)

# %% [markdown]
# ![objectif.jpeg](attachment:objectif.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202020-10-30%20at%2018.46.44.jpeg](attachment:WhatsApp%20Image%202020-10-30%20at%2018.46.44.jpeg)
#
# # Exemple 1
#
# ![1.png](attachment:1.png)

# %% [markdown]
# # Développement:

# %% [markdown]
# #### importation:

# %%
import random
import matplotlib.pyplot as plt

# %% [markdown]
# #### calcule de la moyenne empirique:

# %%
def Xn(t,n):
    x=0
    for j in t:
        x=x+j
    return x/n

# %% [markdown]
# #### calcule de la variance empirique:

# %%
def On(t,n,xn):
    tita=0
    for i in t:
        tita=tita+(i-xn)**2
    return tita/n

# %% [markdown]
# #### création des valeurs alératoires avec la distribution uniforme:

# %%
def creat_alea_table(n):
    t=[]
    for i in range(n+1):
        t.append(random.uniform(0, 1)) #les valeurs de i compris entre 0 et 1.
    return t

# %%
n=[1000,10000,100000,1000000] #les échantillons
titatable=[]
xn=[]
for i in n:
    t=creat_alea_table(i)
    xn.append(Xn(t,i))
    titatable.append(On(t,i,Xn(t,i)))

# %% [markdown]
# #### Représentation graphique:

# %%
plt.plot(n,titatable,'r*')
plt.plot(n,xn,'b*')
plt.xlabel("n:les valeurs alératoires")
plt.ylabel("moyenne/ variance")
plt.show()
for i in range(len(n)):
    print ('Nombre des variables aleatoire Xi est= {} ,la moyenne= {} ,la variance= {}.'.format(n[i],xn[i],titatable[i]))
# Out:
# Nombre des variables aleatoire Xi est= 1000 ,la moyenne= 0.4961828930508174 ,la variance= 0.08803407910832714.
# Nombre des variables aleatoire Xi est= 10000 ,la moyenne= 0.4987009569075517 ,la variance= 0.08291593307387142.
# Nombre des variables aleatoire Xi est= 100000 ,la moyenne= 0.500741997711385 ,la variance= 0.08344368342329733.
# Nombre des variables aleatoire Xi est= 1000000 ,la moyenne= 0.49969343961481144 ,la variance= 0.0833294244239703.

# %% [markdown]
# # Interprétation:

# %% [markdown]
# ##### comparaison la résultat théorique avec les résultats pratique:

# %% [markdown]
# ![e3.jpeg](attachment:e3.jpeg)

# %% [markdown]
# #### conclusion:

# %% [markdown]
# #### D'après le tableau comparatif, on constate que le valeur de la moyenne empirique et la varience empirique sont presque egal l'esperence et la varience theorique quelque soit le nombre de variable aleatoire (N)

# %% [markdown]
# # Exemple 2

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# # Développement:

# %% [markdown]
# #### importation:

# %%
import numpy as np
from ipykernel import kernelapp as app
import math

# %% [markdown]
# #### Déclaration de la fonction f:

# %%
def creat_alea_table(n,lamda):
    t=np.random.exponential(1/lamda,n)
    return t

# %% [markdown]
# #### Représentation graphique:

# %%
xn=[[]]*4
titatable=[[]]*4
lamda=[10,100,1000,10000] # les valeurs de lemda

for i in range(4):
    for j in range(4):
        t=creat_alea_table(n[i],lamda[j])
        x=Xn(t,n[i])
        xn[j].append([x])
        titatable[j].append([On(t,n[i],x)])
        plt.subplot(2,2,1)
        plt.plot(lamda[j],titatable[i][j],'ro')
        plt.xlabel("lemda")
        plt.ylabel("variance")
        plt.subplot(2,2,2)
        plt.plot(lamda[j],x,'bo')
        plt.xlabel("lemda")
        plt.ylabel("espérence")
plt.show()
li=0
ni=0
ii=0
while ii<16:
    if li==4:
        li=0
        ni+=1
    print ('Nombre des variables aleatoire Xi est= {},lemda= {} ,la moyenne= {} ,la variance= {}.'.format(n[ni],lamda[li],xn[0][ii],titatable[0][ii]))
    ii+=1
    li+=1
# Out:
# /home/bacemabr/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # This is added back by InteractiveShellApp.init_path()
# /home/bacemabr/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   from ipykernel import kernelapp as app
# ...

# %% [markdown]
# # Interprétation:

# %% [markdown]
# ##### comparaison la résultat théorique avec les résultats pratique:

# %% [markdown]
# ![WhatsApp%20Image%202020-10-30%20at%2018.58.23.jpeg](attachment:WhatsApp%20Image%202020-10-30%20at%2018.58.23.jpeg)

# %% [markdown]
# ##### conclusion:

# %% [markdown]
# #### D'après le tableau comparatif, on constate que le valeur de la moyenne empirique et la varience empirique sont presque egal l'esperence et la varience theorique quelque soit le nombre de variable aleatoire (N)

# %% [markdown]
# # Exemple 3

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# # Développement:

# %%
def creat_alea_table(n):
    return np.random.randint(0,n+1,n)
print(creat_alea_table(5))
# Out:
# [2 0 2 1 3]

# %% [markdown]
# #### Représentation graphique:

# %%
plt.style.use('seaborn-deep')
xn=[]
tita=[]
for i in n:
    t=creat_alea_table(i)
    x=Xn(t,i)
    xn.append(x)
    tita.append(On(t,i,x))
plt.subplot(2,2,1)
plt.plot(n,tita,'r*')
plt.subplot(2,2,2)
plt.plot(n,xn,'b*')
plt.show()
print(n)
for i in range(len(n)):
    print('Nombre des variables aleatoire Xi est= {} ,la moyenne= {} ,la variance= {}'.format(n[i],xn[i],tita[i]))
# Out:
# [1000, 10000, 100000, 1000000]
# Nombre des variables aleatoire Xi est= 1000 ,la moyenne= 500.524 ,la variance= 85808.90142400007
# Nombre des variables aleatoire Xi est= 10000 ,la moyenne= 5041.7985 ,la variance= 8342114.977497711
# Nombre des variables aleatoire Xi est= 100000 ,la moyenne= 49970.1247 ,la variance= 831157125.2730699
# Nombre des variables aleatoire Xi est= 1000000 ,la moyenne= 500228.923689 ,la variance= 83368684150.93764

# %% [markdown]
# # Interprétation:

# %% [markdown]
# ##### comparaison la résultat théorique avec les résultats pratique:

# %% [markdown]
# ![e1.jpeg](attachment:e1.jpeg)

# %% [markdown]
# ##### conclusion:

# %% [markdown]
# #### D'après le tableau comparatif, on constate que le valeur de la moyenne empirique et la varience empirique sont presque egal l'esperence et la varience theorique quelque soit le nombre de variable aleatoire (N)

# %% [markdown]
# # Exemple 4

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# # Développement:

# %%
def creat_tabe(n):
    x=[]
    t=np.random.uniform(0, 1,n)
    for i in t:
        if i<0.3:
            x.append(0)
        elif i<0.5:
            x.append(2)
        else:
            x.append(6)
    return x

# %%
xn=[]
tita=[]
for i in n:
    t=creat_tabe(i)
    x=Xn(t,i)
    xn.append(x)
    tita.append(On(t,i,x))
for i in range(len(n)):
    print ('Nombre des variables aleatoire Xi est= {} ,la moyenne= {} ,la variance= {}.'.format(n[i],xn[i],tita[i]))
# Out:
# Nombre des variables aleatoire Xi est= 1000 ,la moyenne= 3.19 ,la variance= 7.315899999999966.
# Nombre des variables aleatoire Xi est= 10000 ,la moyenne= 3.3872 ,la variance= 7.24847616000003.
# Nombre des variables aleatoire Xi est= 100000 ,la moyenne= 3.40538 ,la variance= 7.244627055600232.
# Nombre des variables aleatoire Xi est= 1000000 ,la moyenne= 3.399932 ,la variance= 7.236006395330777.

# %% [markdown]
# # Interprétation:
# ##### comparaison la résultat théorique avec les résultats pratique:
# ![WhatsApp%20Image%202020-10-30%20at%2018.23.56.jpeg](attachment:WhatsApp%20Image%202020-10-30%20at%2018.23.56.jpeg)

# %% [markdown]
# ##### conclusion:

# %% [markdown]
# #### D'après le tableau comparatif, on constate que le valeur de la moyenne empirique et la varience empirique sont presque egal l'esperence et la varience theorique quelque soit le nombre de variable aleatoire (N)

# %% [markdown]
# ## <center> Conclusion génerale </center>
#
# ![conc.jpeg](attachment:conc.jpeg)
